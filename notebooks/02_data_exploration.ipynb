# %%
import numpy as npy
import pandas as pd

import git #pip install GitPython
from pathlib import Path

# %%
PROJECT_DIR = Path(git.Repo(".", search_parent_directories=True).working_tree_dir)
DATA_DIR = PROJECT_DIR /  "data/raw"

# %%
pd.read_csv(DATA_DIR/"anime_with_synopsis.csv")
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
pd.read_csv(DATA_DIR/"anime.csv")
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
pd.read_csv(DATA_DIR/"animelist.csv")
# Out:
#            user_id  anime_id  rating  watching_status  watched_episodes
# 0                0        67       9                1                 1
# 1                0      6702       7                1                 4
# 2                0       242      10                1                 4
# 3                0      4898       0                1                 1
# 4                0        21      10                1                 0
# ...            ...       ...     ...              ...               ...
# 109224742   353404       507       7                2                 2
# 109224743   353404       392       9                2               112
# 109224744   353404       882       6                2                 1
# 109224745   353404       883       8                2                 1
# 109224746   353404       149       0                6                 0
#
# [109224747 rows x 5 columns]

# %%
pd.read_csv(DATA_DIR/"rating_complete.csv")
# Out:
#           user_id  anime_id  rating
# 0               0       430       9
# 1               0      1004       5
# 2               0      3010       7
# 3               0       570       7
# 4               0      2762       9
# ...           ...       ...     ...
# 57633273   353404       502       8
# 57633274   353404       987       4
# 57633275   353404       225       8
# 57633276   353404       243       7
# 57633277   353404       896       7
#
# [57633278 rows x 3 columns]

# %%
pd.read_csv(DATA_DIR/"watching_status.csv")
# Out:
#    status         description
# 0       1  Currently Watching
# 1       2           Completed
# 2       3             On Hold
# 3       4             Dropped
# 4       6       Plan to Watch

# %%
df_synop = pd.read_csv(DATA_DIR/"anime_with_synopsis.csv")
df_full = pd.read_csv(DATA_DIR/"anime.csv")

# %%
df_anime = df_synop.join(df_full, on='MAL_ID', rsuffix='r')
df_anime = df_anime[['Name','Score', 'Genres', 'sypnopsis', 'Type']]
df_anime
# Out:
#                                   Name    Score  \
# 0                         Cowboy Bebop     8.78
# 1      Cowboy Bebop: Tengoku no Tobira     8.39
# 2                               Trigun     8.24
# 3                   Witch Hunter Robin     7.27
# 4                       Bouken Ou Beet     6.98
# ...                                ...      ...
# 16209  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210                     Mieruko-chan  Unknown
# 16211  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212      Yama no Susume: Next Summit  Unknown
# 16213                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...

# %%
df_anime_tv = df_anime.loc[df_anime["Type"]=="TV"]
df_anime_tv['Score']
# Out:
# 1          8.39
# 2          8.24
# 3          7.27
# 4          6.98
# 5          7.95
#          ...
# 6769        6.4
# 6770        6.7
# 6771    Unknown
# 6775       7.34
# 6777       6.39
# Name: Score, Length: 2193, dtype: object

# %%
df_anime_tv['Score']=pd.to_numeric(df_anime_tv['Score'], errors='coerce')
# Out:
# /tmp/ipykernel_76650/2490423921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anime_tv['Score']=pd.to_numeric(df_anime_tv['Score'], errors='coerce')

# %%
df_anime_tv.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Score'}>]], dtype=object)

# %%
df_anime_tv.loc['Score']
# Out:
# Name         NaN
# Score        NaN
# Genres       NaN
# sypnopsis    NaN
# Type         NaN
# Name: Score, dtype: object

# %%
# Out:
#       test
# 0       23
# 1       27
# 2       79
# 3       96
# 4       14
# ...    ...
# 9995    19
# 9996    54
# 9997    82
# 9998    95
# 9999    17
#
# [10000 rows x 1 columns]

# %%
db_raw['Score']
# Out:
# 0           8.78
# 1           8.39
# 2           8.24
# 3           7.27
# 4           6.98
#           ...
# 17557    Unknown
# 17558    Unknown
# 17559    Unknown
# 17560    Unknown
# 17561    Unknown
# Name: Score, Length: 17562, dtype: object
