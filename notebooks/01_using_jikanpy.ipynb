# %% [markdown]
# This notebook shows you how to scrap information from MyAnimeList.net using jikanpy

# %% [markdown]
# ### Data source:
# - MyAnimeList.net has a good list of upcoming animes.
# - You can also find a list of APIs to mine data from their website at https://myanimelist.net/apiconfig/references/api/v2
# - There is also an unofficial API which can be found here https://jikan.moe/. This version also has a Python wrapper. Details can be found here https://github.com/abhinavk99/jikanpy

# %% [markdown]
# ### Data exploration/ pre-processing:

# %% [markdown]
# Jikan is a api that is designed to collect data from MAL. Here's some example code:

# %%
import pandas as pd
from pprint import pprint
from jikanpy import Jikan

# %%
#Initialize an object
jikan = Jikan()

# %%
#You can search for a particular anime using .search function
search_result = jikan.search('anime', 'Naruto', page=1)
pprint([search_result['results'][i]['title'] for i in range(len(search_result))])
# Out:
# ['Naruto: Shippuuden',
#  'The Last: Naruto the Movie',
#  'Boruto: Naruto the Movie',
#  'Naruto: Shippuuden Movie 4 - The Lost Tower',
#  'Naruto: Shippuuden Movie 2 - Kizuna',
#  'Naruto: Shippuuden Movie 5 - Blood Prison',
#  'Naruto: Shippuuden Movie 6 - Road to Ninja',
#  'Boruto: Naruto the Movie - Naruto ga Hokage ni Natta Hi',
#  'Naruto: Shippuuden Movie 1',
#  'Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo!']

# %%
naruto_id = search_result['results'][0]['mal_id']
naruto = jikan.anime(naruto_id)
pprint(naruto)
# Out:
# {'API_DEPRECATION': True,
#  'API_DEPRECATION_DATE': '2022-02-10T16:02:50+00:00',
#  'API_DEPRECATION_INFO': 'https://bit.ly/jikan-v3-deprecation',
#  'aired': {'from': '2007-02-15T00:00:00+00:00',
#            'prop': {'from': {'day': 15, 'month': 2, 'year': 2007},
#                     'to': {'day': 23, 'month': 3, 'year': 2017}},
#            'string': 'Feb 15, 2007 to Mar 23, 2017',
#            'to': '2017-03-23T00:00:00+00:00'},
#  'airing': False,
#  'background': None,
#  'broadcast': 'Thursdays at 19:30 (JST)',
#  'demographics': [{'mal_id': 27,
#                    'name': 'Shounen',
#                    'type': 'anime',
#                    'url': 'https://myanimelist.net/anime/genre/27/Shounen'}],
#  'duration': '23 min per ep',
#  'ending_themes': ['1:\xa0"Nagare Boshi ~Shooting Star~ (流れ星〜Shooting Star〜)" '
#                    'by HOME MADE Kazoku\xa0(eps 1-18)',
#                    '2:\xa0"Michi ~to you all (道 〜to you all)" by aluto\xa0(eps '
#                    '19-30)',
#                    '3:\xa0"KIMI MONOGATARI (キミモノガタリ)" by little by little\xa0'
#                    '(eps 31-41)',
#                    '4:\xa0"Mezamero! Yasei (目覚めろ!野性)" by MATCHY with '
#                    'QUESTION?\xa0(eps 42-53)',
#                    '5:\xa0"Sunao na Niji (素直な虹)" by surface\xa0(eps 54-63)',
#                    '6:\xa0"BROKEN YOUTH" by NICO Touches the Walls\xa0(eps '
#                    '64-77)',
#                    '7:\xa0"Long Kiss Goodbye" by HALCALI\xa0(eps 78-90)',
#                    '8:\xa0"BACCHIKOI!!! (バッチコイ!!!)" by DEV PARADE\xa0(eps '
#                    '91-102)',
#                    '9:\xa0"Shinkokyuu (深呼吸)" by SUPER BEAVER\xa0(eps 103-115)',
#                    '10:\xa0"My ANSWER" by SEAMO\xa0(eps 116-128)',
#                    '11:\xa0"Omae Dattanda (おまえだったんだ)" by Kishidan\xa0(eps '
#                    '129-141)',
#                    '12:\xa0"For You" by AZU\xa0(eps 142-153)',
#                    '13:\xa0"Jitensha (自転車)" by OreSkaBand\xa0(eps 154-166)',
#                    '14:\xa0"Utakata Hanabi (うたかた花火)" by supercell\xa0(eps '
#                    '167-179)',
#                    '15:\xa0"U can do it!" by DOMINO\xa0(eps 180-192)',
#                    '16:\xa0"Mayonaka no Orchestra (真夜中のオーケストラ)" by Aqua '
#                    'Timez\xa0(eps 193-205)',
#                    '17:\xa0"FREEDOM" by HOME MADE Kazoku\xa0(eps 206-218)',
#                    '18:\xa0"Yokubou o Sakebe!!!! (欲望を叫べ!!!!)" by OKAMOTO\'S\xa0'
#                    '(eps 219-230)',
#                    '19:\xa0"Place to Try" by TOTALFAT\xa0(eps 231-242)',
#                    '20:\xa0"By My Side (バイマイサイド)" by Hemenway\xa0(eps 243-256)',
#                    '21:\xa0"Cascade (カスケード)" by UNLIMITS\xa0(eps 257-268)',
#                    '22:\xa0"Kono Koe Karashite (この声枯らしてfeat. CHEHON)" by AISHA '
#                    'feat. CHEHON\xa0(eps 267-281)',
#                    '23:\xa0"MOTHER" by MUCC\xa0(eps 282-295)',
#                    '24:\xa0"Sayonara Memory (さよならメモリー)" by 7!!\xa0(eps '
#                    '296-306)',
#                    '25:\xa0"I Can Hear" by DISH//\xa0(eps 307-319)',
#                    '26:\xa0"Yume wo Daite ~Hajimari no Crissroad~ '
#                    '(夢を抱いて〜はじまりのクリスロード〜)" by Rake\xa0(eps 320-332)',
#                    '27:\xa0"Black Night Town (ブラックナイトタウン)" by Akihisa '
#                    'Kondou\xa0(eps 333-343)',
#                    '28:\xa0"Niji (虹)" by Shinkuu Horou (真空ホロウ)\xa0(eps '
#                    '344-356)',
#                    '29:\xa0"FLAME" by DISH//\xa0(eps 357-366)',
#                    '30:\xa0"Never Change feat.Lyu:Lyu" by SHUN\xa0(eps '
#                    '367-379)',
#                    '31:\xa0"Dame Dame da (だめだめだ)" by Shiori Tomita\xa0(eps '
#                    '380-393)',
#                    '32:\xa0"Spinning World" by Diana Garnet\xa0(eps 394-405)',
#                    '33:\xa0"Kotoba no Iranai Yakusoku (言葉のいらない約束)" by sana\xa0'
#                    '(eps 406-417)',
#                    '34:\xa0"Niji no Sora (虹の空)" by FLOW\xa0(eps 418-431)',
#                    '35:\xa0"Trouble Maker (トラブルメイカー)" by KANIKAPILA\xa0(eps '
#                    '432-443)',
#                    '36:\xa0"Sonna Kimi, Konna Boku (そんな君、こんな僕)" by Thinking '
#                    'Dogs\xa0(eps 444-454)',
#                    '37:\xa0"Ao no Lullaby (青のララバイ)" by Kuroneko Chelsea\xa0'
#                    '(eps 455-466)',
#                    '38:\xa0"Pino to Amélie (ピノとアメリ)" by Huwie Ishizaki\xa0(eps '
#                    '467-479)',
#                    '39:\xa0"Tabidachi no Uta (旅立ちの唄)" by Ayumikurikamaki\xa0'
#                    '(eps 480-488)',
#                    '40:\xa0"Zetsu Zetsu (『絶絶（ぜつぜつ）)" by Swimy\xa0(eps '
#                    '489-500)'],
#  'episodes': 500,
#  'explicit_genres': [],
#  'external_links': [{'name': 'Official Site',
#                      'url': 'http://www.tv-tokyo.co.jp/anime/naruto/'},
#                     {'name': 'AnimeDB',
#                      'url': 'http://anidb.info/perl-bin/animedb.pl?show=anime&aid=4880'},
#                     {'name': 'AnimeNewsNetwork',
#                      'url': 'http://www.animenewsnetwork.com/encyclopedia/anime.php?id=7293'},
#                     {'name': 'Wikipedia',
#                      'url': 'http://en.wikipedia.org/wiki/Naruto'},
#                     {'name': '\n    \n  ',
#                      'url': 'https://naruto.fandom.com/wiki/Naruto:_Shipp%C5%ABden'}],
#  'favorites': 98753,
#  'genres': [{'mal_id': 1,
#              'name': 'Action',
#              'type': 'anime',
#              'url': 'https://myanimelist.net/anime/genre/1/Action'},
#             {'mal_id': 2,
#              'name': 'Adventure',
#              'type': 'anime',
#              'url': 'https://myanimelist.net/anime/genre/2/Adventure'},
#             {'mal_id': 10,
#              'name': 'Fantasy',
#              'type': 'anime',
#              'url': 'https://myanimelist.net/anime/genre/10/Fantasy'}],
#  'headers': {'Access-Control-Allow-Methods': '*',
#              'Access-Control-Allow-Origin': '*',
#              'Cache-Control': 'private, must-revalidate',
#              'Connection': 'keep-alive',
#              'Content-Encoding': 'gzip',
#              'Content-Length': '4710',
#              'Content-Type': 'application/json',
#              'Date': 'Fri, 22 Jul 2022 05:10:35 GMT',
#              'ETag': '"b4826170fa4eab3e1d211afcb0a9436d"',
#              'Expires': 'Fri, 22 Jul 2022 03:50:28 GMT',
#              'Server': 'nginx/1.18.0 (Ubuntu)',
#              'Vary': 'Accept-Encoding',
#              'X-API-Deprecation': '1',
#              'X-API-Deprecation-Date': '2022-02-10T16:02:50+00:00',
#              'X-API-Deprecation-Info': 'https://bit.ly/jikan-v3-deprecation',
#              'X-Cache-Status': 'UPDATING',
#              'X-Request-Cache-Ttl': '11630',
#              'X-Request-Cached': '1',
#              'X-Request-Hash': 'request:anime:5cc3e6d22a397a9cf680ba43a2095af9719063d8'},
#  'image_url': 'https://cdn.myanimelist.net/images/anime/1565/111305.jpg',
#  'jikan_url': 'https://api.jikan.moe/v3/anime/1735',
#  'licensors': [{'mal_id': 119,
#                 'name': 'VIZ Media',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/119/VIZ_Media'}],
#  'mal_id': 1735,
#  'members': 2148937,
#  'opening_themes': ['1:\xa0"Hero\'s Come Back" by Nobodyknows+\xa0(eps 1-30)',
#                     '2:\xa0"distance" by LONG SHOT PARTY\xa0(eps 31-53)',
#                     '3:\xa0"Blue Bird (ブルーバード)" by Ikimonogakari\xa0(eps '
#                     '54-77)',
#                     '4:\xa0"CLOSER" by Inoue Joe\xa0(eps 78-102)',
#                     '5:\xa0"Hotaru no Hikari (ホタルノヒカリ)" by Ikimonogakari\xa0'
#                     '(eps 103-128)',
#                     '6:\xa0"Sign" by FLOW\xa0(eps 129-153)',
#                     '7:\xa0"Toumei Datta Sekai (透明だった世界)" by Motohiro Hata\xa0'
#                     '(eps 152-179)',
#                     '8:\xa0"Diver" by NICO Touches the Walls\xa0(eps 180-205)',
#                     '9:\xa0"Lovers (ラヴァーズ)" by 7!!\xa0(eps 206-230)',
#                     '10:\xa0"newsong" by tacica\xa0(eps 231-256)',
#                     '11:\xa0"Totsugeki Rock (突撃ロック)" by THE CRO-MAGNONS\xa0'
#                     '(eps 257-281)',
#                     '12:\xa0"Moshimo" by Daisuke\xa0(eps 282-306)',
#                     '13:\xa0"Niwaka Ame Nimo Makezu (ニワカ雨ニモ負ケズ)" by NICO '
#                     'Touches the Walls\xa0(eps 307-332)',
#                     '14:\xa0"Tsuki no Ookisa (月の大きさ)" by Nogizaka46\xa0(eps '
#                     '333-356)',
#                     '15:\xa0"Guren" by DOES\xa0(eps 357-379)',
#                     '16:\xa0"Silhouette (シルエット)" by KANA-BOON\xa0(eps 380-405)',
#                     '17:\xa0"Kaze (風)" by Yamazaru\xa0(eps 406-431)',
#                     '18:\xa0"LINE" by Sukima Switch\xa0(eps 432-458)',
#                     '19:\xa0"Blood Circulator (ブラッドサーキュレーター)" by Asian Kung-Fu '
#                     'Generation\xa0(eps 459-479)',
#                     '20:\xa0"Kara no Kokoro (カラノココロ)" by Anly\xa0(eps '
#                     '480-500)'],
#  'popularity': 16,
#  'premiered': 'Winter 2007',
#  'producers': [{'mal_id': 16,
#                 'name': 'TV Tokyo',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/16/TV_Tokyo'},
#                {'mal_id': 17,
#                 'name': 'Aniplex',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/17/Aniplex'},
#                {'mal_id': 50,
#                 'name': 'KSS',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/50/KSS'},
#                {'mal_id': 211,
#                 'name': 'Rakuonsha',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/211/Rakuonsha'},
#                {'mal_id': 717,
#                 'name': 'TV Tokyo Music',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/717/TV_Tokyo_Music'},
#                {'mal_id': 1365,
#                 'name': 'Shueisha',
#                 'type': 'anime',
#                 'url': 'https://myanimelist.net/anime/producer/1365/Shueisha'}],
#  'rank': 283,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related': {'Adaptation': [{'mal_id': 11,
#                              'name': 'Naruto',
#                              'type': 'manga',
#                              'url': 'https://myanimelist.net/manga/11/Naruto'},
#                             {'mal_id': 86129,
#                              'name': 'Naruto Hiden Series',
#                              'type': 'manga',
#                              'url': 'https://myanimelist.net/manga/86129/Naruto_Hiden_Series'},
#                             {'mal_id': 90531,
#                              'name': 'Naruto Shinden Series',
#                              'type': 'manga',
#                              'url': 'https://myanimelist.net/manga/90531/Naruto_Shinden_Series'},
#                             {'mal_id': 118852,
#                              'name': 'Nambā Fū no Sho: Sugao no Shinjitsu...!!',
#                              'type': 'manga',
#                              'url': 'https://myanimelist.net/manga/118852/Nambā_Fū_no_Sho__Sugao_no_Shinjitsu'}],
#              'Other': [{'mal_id': 10075,
#                         'name': 'Naruto x UT',
#                         'type': 'anime',
#                         'url': 'https://myanimelist.net/anime/10075/Naruto_x_UT'},
#                        {'mal_id': 19511,
#                         'name': 'Naruto: Shippuuden - Sunny Side Battle',
#                         'type': 'anime',
#                         'url': 'https://myanimelist.net/anime/19511/Naruto__Shippuuden_-_Sunny_Side_Battle'},
#                        {'mal_id': 40971,
#                         'name': 'Newsong',
#                         'type': 'anime',
#                         'url': 'https://myanimelist.net/anime/40971/Newsong'}],
#              'Prequel': [{'mal_id': 20,
#                           'name': 'Naruto',
#                           'type': 'anime',
#                           'url': 'https://myanimelist.net/anime/20/Naruto'}],
#              'Sequel': [{'mal_id': 28755,
#                          'name': 'Boruto: Naruto the Movie',
#                          'type': 'anime',
#                          'url': 'https://myanimelist.net/anime/28755/Boruto__Naruto_the_Movie'},
#                         {'mal_id': 34566,
#                          'name': 'Boruto: Naruto Next Generations',
#                          'type': 'anime',
#                          'url': 'https://myanimelist.net/anime/34566/Boruto__Naruto_Next_Generations'}],
#              'Side story': [{'mal_id': 2472,
#                              'name': 'Naruto: Shippuuden Movie 1',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/2472/Naruto__Shippuuden_Movie_1'},
#                             {'mal_id': 4437,
#                              'name': 'Naruto: Shippuuden Movie 2 - Kizuna',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/4437/Naruto__Shippuuden_Movie_2_-_Kizuna'},
#                             {'mal_id': 6325,
#                              'name': 'Naruto: Shippuuden Movie 3 - Hi no Ishi '
#                                      'wo Tsugu Mono',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/6325/Naruto__Shippuuden_Movie_3_-_Hi_no_Ishi_wo_Tsugu_Mono'},
#                             {'mal_id': 8246,
#                              'name': 'Naruto: Shippuuden Movie 4 - The Lost '
#                                      'Tower',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/8246/Naruto__Shippuuden_Movie_4_-_The_Lost_Tower'},
#                             {'mal_id': 10589,
#                              'name': 'Naruto: Shippuuden Movie 5 - Blood '
#                                      'Prison',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/10589/Naruto__Shippuuden_Movie_5_-_Blood_Prison'},
#                             {'mal_id': 13667,
#                              'name': 'Naruto: Shippuuden Movie 6 - Road to '
#                                      'Ninja',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/13667/Naruto__Shippuuden_Movie_6_-_Road_to_Ninja'},
#                             {'mal_id': 16870,
#                              'name': 'The Last: Naruto the Movie',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/16870/The_Last__Naruto_the_Movie'},
#                             {'mal_id': 32365,
#                              'name': 'Boruto: Naruto the Movie - Naruto ga '
#                                      'Hokage ni Natta Hi',
#                              'type': 'anime',
#                              'url': 'https://myanimelist.net/anime/32365/Boruto__Naruto_the_Movie_-_Naruto_ga_Hokage_ni_Natta_Hi'}],
#              'Spin-off': [{'mal_id': 4134,
#                            'name': 'Naruto: Shippuuden - Shippuu! "Konoha '
#                                    'Gakuen" Den',
#                            'type': 'anime',
#                            'url': 'https://myanimelist.net/anime/4134/Naruto__Shippuuden_-_Shippuu_Konoha_Gakuen_Den'},
#                           {'mal_id': 12979,
#                            'name': 'Naruto SD: Rock Lee no Seishun Full-Power '
#                                    'Ninden',
#                            'type': 'anime',
#                            'url': 'https://myanimelist.net/anime/12979/Naruto_SD__Rock_Lee_no_Seishun_Full-Power_Ninden'}]},
#  'request_cache_expiry': 11630,
#  'request_cached': True,
#  'request_hash': 'request:anime:5cc3e6d22a397a9cf680ba43a2095af9719063d8',
#  'score': 8.24,
#  'scored_by': 1443868,
#  'source': 'Manga',
#  'status': 'Finished Airing',
#  'studios': [{'mal_id': 1,
#               'name': 'Pierrot',
#               'type': 'anime',
#               'url': 'https://myanimelist.net/anime/producer/1/Pierrot'}],
#  'synopsis': 'It has been two and a half years since Naruto Uzumaki left '
#              'Konohagakure, the Hidden Leaf Village, for intense training '
#              'following events which fueled his desire to be stronger. Now '
#              'Akatsuki, the mysterious organization of elite rogue ninja, is '
#              'closing in on their grand plan which may threaten the safety of '
#              'the entire shinobi world. Although Naruto is older and sinister '
#              'events loom on the horizon, he has changed little in '
#              'personality—still rambunctious and childish—though he is now far '
#              'more confident and possesses an even greater determination to '
#              'protect his friends and home. Come whatever may, Naruto will '
#              'carry on with the fight for what is important to him, even at '
#              'the expense of his own body, in the continuation of the saga '
#              'about the boy who wishes to become Hokage. [Written by MAL '
#              'Rewrite]',
#  'themes': [{'mal_id': 17,
#              'name': 'Martial Arts',
#              'type': 'anime',
#              'url': 'https://myanimelist.net/anime/genre/17/Martial_Arts'}],
#  'title': 'Naruto: Shippuuden',
#  'title_english': 'Naruto Shippuden',
#  'title_japanese': 'ナルト- 疾風伝',
#  'title_synonyms': ['Naruto Hurricane Chronicles'],
#  'trailer_url': 'https://www.youtube.com/embed/1dy2zPPrKD0?enablejsapi=1&wmode=opaque&autoplay=1',
#  'type': 'TV',
#  'url': 'https://myanimelist.net/anime/1735/Naruto__Shippuuden'}

# %%
#Available data on MAL
archive = jikan.season_archive()
pprint(archive['archive'])
# Out:
# [{'seasons': ['Winter'], 'year': 2023},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2022},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2021},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2020},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2019},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2018},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2017},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2016},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2015},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2014},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2013},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2012},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2011},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2010},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2009},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2008},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2007},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2006},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2005},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2004},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2003},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2002},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2001},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 2000},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1999},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1998},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1997},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1996},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1995},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1994},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1993},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1992},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1991},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1990},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1989},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1988},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1987},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1986},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1985},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1984},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1983},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1982},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1981},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1980},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1979},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1978},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1977},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1976},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1975},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1974},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1973},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1972},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1971},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1970},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1969},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1968},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1967},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1966},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1965},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1964},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1963},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1962},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1961},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1960},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1959},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1958},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1957},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1956},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1955},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1954},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1953},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1952},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1951},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1950},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1949},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1948},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1947},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1946},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1945},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1944},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1943},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1942},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1941},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1940},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1939},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1938},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1937},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1936},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1935},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1934},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1933},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1932},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1931},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1930},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1929},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1928},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1927},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1926},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1925},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1924},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1923},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1922},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1921},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1920},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1919},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1918},
#  {'seasons': ['Winter', 'Spring', 'Summer', 'Fall'], 'year': 1917}]

# %%
#You can query for all animes from a particular season, and year
winter_2018_anime = jikan.season(year=2018, season='winter')
pprint([ winter_2018_anime['anime'][i]['title'] for i in range(len(winter_2018_anime))])
# Out:
# ['Violet Evergarden',
#  'Darling in the FranXX',
#  'Nanatsu no Taizai: Imashime no Fukkatsu',
#  'Overlord II',
#  'Saiki Kusuo no Ψ-nan 2',
#  'Karakai Jouzu no Takagi-san',
#  'Citrus',
#  'Sora yori mo Tooi Basho',
#  'Death March kara Hajimaru Isekai Kyousoukyoku',
#  'Yuru Camp△',
#  'Gakuen Babysitters']

# %%
years = [year for year in range (2022, 2023)]
seasons = ['winter', 'spring', 'summer', 'fall']

myanimelist = []

# %%
# Retrieve anime data through Jikan
for year in years:
    for season in seasons:
        myanimelist.append(jikan.season(year = year, season = season))

# %%
# Collect all necessary attributes: Title, Score, Members, Genre, Producers, Year, Season and Synopsis
animedata = []
for animeseason in myanimelist:
    for show in animeseason['anime']:
        animedata.append([show['title'], show['score'], show['members'], ', '.join(genre['name'] for genre in show['genres']), 
                        ', '.join(producer['name'] for producer in show['producers']), animeseason["season_year"],
                        animeseason["season_name"], show['synopsis']])

# %%
# Create a dataframe to store Anime data and remove duplicate entries
anime_df = pd.DataFrame(animedata, columns = ["Title", "Score", "Members", "Genre", "Producers", "Year", "Season", "Synopsis"])
anime_df.drop_duplicates(subset= "Title", keep = 'first', inplace = True)
anime_df.index.name = "ID"

# %%
anime_df.head()
# Out:
#                                               Title  Score  Members  \
# ID
# 0                     Kimetsu no Yaiba: Yuukaku-hen   8.86   932000
# 1       Shingeki no Kyojin: The Final Season Part 2   8.82   900000
# 2                   Sono Bisque Doll wa Koi wo Suru   8.34   717000
# 3   Arifureta Shokugyou de Sekai Saikyou 2nd Season   7.21   276000
# 4           Tensai Ouji no Akaji Kokka Saisei Jutsu   7.42   195000
#
#                          Genre               Producers  Year  Season  \
# ID
# 0              Action, Fantasy                ufotable  2022  Winter
# 1                Action, Drama                   MAPPA  2022  Winter
# 2       Romance, Slice of Life             CloverWorks  2022  Winter
# 3   Action, Adventure, Fantasy  asread., studio MOTHER  2022  Winter
# 4              Comedy, Fantasy  Yokohama Animation Lab  2022  Winter
#
#                                              Synopsis
# ID
# 0   The devastation of the Mugen Train incident st...
# 1   Turning against his former allies and enemies ...
# 2   High school student Wakana Gojou spends his da...
# 3   Transported to another world and left behind b...
# 4   The king of Natra has fallen ill, leaving the ...

# %%
#To save as a .csv file
anime_df.to_csv('../data/anime_data.csv', index=True)

# %%
anime_df = pd.read_csv('../data/anime_data.csv')
